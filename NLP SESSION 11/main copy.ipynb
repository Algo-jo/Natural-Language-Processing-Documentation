# %%
import pandas as pd

DATA_PATH = 'jobpostingdata.csv'
MODEL_PATH = 'model.pkl'

# %%
df = pd.read_csv(DATA_PATH)
df.head() # 1 -> Fake
# Out:
#                         title  fraudulent  \
# 0               PHP Developer           0
# 1     CUSTOMER SERVICE AGENT            1
# 2       VP Marketing & Growth           0
# 3  SAP BW Developer/Architect           1
# 4    Administrative Assistant           1
#
#                                                 text
# 0  PHP Developer You're a skilled developer. You ...
# 1  CUSTOMER SERVICE AGENT  Aegis is a global busi...
# 2  VP Marketing & Growth Depop is an exciting new...
# 3  SAP BW Developer/Architect  Assist with Full L...
# 4  Administrative Assistant With decades of exper...

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag

# %%
def get_tag(tag:str):
    if tag[0] in ['V', 'N', 'R']:
        return tag[0].lower()
    elif tag[0] == 'J':
        return 'a'
    else:
        return 'n'

def lemmatization(tokens):
    lemmatizer = WordNetLemmatizer()
    tagged = pos_tag(tokens)
    lemmatized = []
    for token, tag in tagged:
        result = lemmatizer.lemmatize(token, get_tag(tag))
        lemmatized.append(result)
    return lemmatized

def text_preprocessor(sentence : str):
    eng_stopword = stopwords.words('english')
    tokens = word_tokenize(sentence)
    cleaned = [
        token.lower() for token in tokens if token not in eng_stopword
        and
        token.isalpha()
    ]
    
    lemmatized = lemmatization(cleaned)
    return lemmatized

# %%
# sentence: extracted feature
# existed words: unique words in corpus
def feature_extraction(sentence, existed_words):
    unique_words = set(text_preprocessor(sentence))
    feature = {}
    for word in existed_words:
        feature[word] = (word in unique_words)
        
    return feature

# %%
from nltk.classify.naivebayes import NaiveBayesClassifier
from nltk.classify import accuracy
from sklearn.model_selection import train_test_split

# %%
def train_classifier():
    x = df['text']
    y = df['fraudulent']
    corpus = ' '.join(x)
    existed_words = set(text_preprocessor(corpus))
    
    # [({feature}, category), ()]  
    features = [
        (feature_extraction(sentence, existed_words), category) 
        for sentence, category in zip(x, y)
    ]
    
    train_data, test_data = train_test_split(
        features, test_size=0.2, random_state=42
    )
    
    classifier = NaiveBayesClassifier.train(train_data)
    accuracy_percentage = accuracy(classifier, test_data) * 100
    print(f"Accuracy: {accuracy_percentage}%")
    
    return classifier, existed_words

# %%
train_classifier()
# Out:
# Accuracy: 75.0%
# (<nltk.classify.naivebayes.NaiveBayesClassifier at 0x1b9ea5330e0>,
#  {'telephone',
#   'editdwe',
#   'agenciesmanage',
#   'ann',
#   'receptionists',
#   'programswillingness',
#   'vol',
#   'quantify',
#   'chemistry',
#   'expense',
#   'drop',
#   'poise',
#   'sheer',
#   'capable',
#   'removal',
#   'life',
#   'industryknowledge',
#   'strand',
#   'robert',
#   'macbook',
#   'sir',
#   'supervisorfollow',
#   'player',
#   'lawyer',
#   'proactive',
#   'express',
#   'copywriting',
#   'fox',
#   'seedcampwork',
#   'happily',
#   'environmentif',
#   'populo',
#   'μικρή',
#   'lan',
#   'dotool',
#   'masseuselaundry',
#   'wilsonart',
#   'demothey',
#   'fracturing',
#   'resistance',
#   'neededenter',
#   'algorithms',
#   'perhaps',
#   'suction',
#   'filesmaintain',
#   'analystsfamiliarity',
#   'detailability',
#   'vcenter',
#   'staffrecruiting',
#   'everyone',
#   'networker',
#   'ασοεετην',
#   'servicesongoing',
#   'somebody',
#   'w',
#   'principal',
#   'discretionwilling',
#   'feelthis',
#   'await',
#   'χρόνος',
#   'behaviourleverage',
#   'outing',
#   'ceo',
#   'stimulate',
#   'yearlending',
#   'dish',
#   'twilio',
#   'doingyou',
#   'customersaddressing',
#   'sellerprepare',
#   'εργασίαςτο',
#   'αγγελίες',
#   'alto',
#   'descriptionurban',
#   'healthcare',
#   'learnerdetail',
#   'analystscoordinate',
#   'suspicion',
#   'wellprovides',
#   'roof',
#   'caliper',
#   'specific',
#   'petty',
#   'kitchencycle',
#   'tasks',
#   'ireland',
#   'crew',
#   'offerweekly',
#   'mainly',
#   'coowe',
#   'chargeable',
#   'teams',
#   'lovefilm',
#   'συμμετέχουμε',
#   'airfy',
#   'superb',
#   'responsibilitiesdevelop',
#   'motivate',
#   'color',
#   'repair',
#   'quoyou',
#   'predictable',
#   'guide',
#   'frank',
#   'useful',
#   'initiativesensure',
#   'poised',
#   'repeat',
#   'tim',
#   'your',
#   'neededperforms',
#   'ebay',
#   'recur',
#   'logs',
#   'acls',
#   'requiredwork',
#   'alison',
#   'belt',
#   'clientsexcellent',
#   'inclusive',
#   'airbrake',
#   'ethernet',
#   'internal',
#   'upload',
#   'sl',
#   'vcac',
#   'metus',
#   'pipelinemanaging',
#   'desirablequalifications',
#   'feed',
#   'refeição',
#   'accountablegym',
#   'scada',
#   'youwe',
#   'project',
#   'environmentstocked',
#   'qualitylive',
#   'paycheck',
#   'optionsgreat',
#   'principles',
#   'geometrics',
#   'πώληση',
#   'resourceful',
#   'demo',
#   'cashier',
#   'reits',
#   'travelgreeting',
#   'netweaver',
#   'trainingaccrued',
#   'efficitur',
#   'bonus',
#   'shortage',
#   'peopletogether',
#   'είναι',
#   'try',
#   'four',
#   'centrally',
#   'salarywork',
#   'enter',
#   'detailparticipate',
#   'skillsdemonstrated',
#   'music',
#   'clientparticipate',
#   'tdd',
#   'heard',
#   'configuration',
#   'napkins',
#   'compliance',
#   'bespeak',
#   'javascript',
#   'codie',
#   'uservoiceresolve',
#   'strategyevaluates',
#   'usersparticipating',
#   'cross',
#   'sarcastic',
#   'toolsresearch',
#   'industryexperience',
#   'strictly',
#   'repeatable',
#   'financing',
#   'manageranswer',
#   'illustration',
#   'wholeheartedly',
#   'agile',
#   'eoo',
#   'paid',
#   'levelsinteract',
#   'multivariate',
#   'begin',
#   'satisfactory',
#   'buy',
#   'familiarity',
#   'wdc',
#   'designers',
#   'responsibilitiesexcellent',
#   'velcro',
#   'legitimate',
#   'inbox',
#   'stake',
#   'closeout',
#   'sand',
#   'ops',
#   'biotechnology',
#   'waterfall',
#   'succession',
#   'tourism',
#   'accuracy',
#   'structural',
#   'morgan',
#   'sapphire',
#   'unix',
#   'innovate',
#   'integration',
#   'extreme',
#   'applicantsan',
#   'bravo',
#   'exotic',
#   'esri',
#   'relationshipscontact',
#   'beaufort',
#   'pireusfriendly',
#   'εξαιρετικό',
#   'england',
#   'marketable',
#   'amenity',
#   'luxembourg',
#   'labs',
#   'buyback',
#   'departure',
#   'essentialstrong',
#   'cocoa',
#   'spearhead',
#   'lift',
#   'rue',
#   'raidimplementations',
#   'connectivity',
#   'meaty',
#   'flood',
#   'abound',
#   'req',
#   'orientedhotel',
#   'stratigraphy',
#   'tasksdriven',
#   'μαςπροηγούμενη',
#   'affiliation',
#   'demonstrator',
#   'comms',
#   'programme',
#   'valetta',
#   'evident',
#   'malesuada',
#   'simplicity',
#   'exceeds',
#   'προοπτική',
#   'underpin',
#   'leadershipsignificant',
#   'pdq',
#   'yessalary',
#   'understood',
#   'pivotal',
#   'dakota',
#   'improvements',
#   'pass',
#   'deadlinesoutside',
#   'wizard',
#   'programsexposure',
#   'projectprivate',
#   'key',
#   'successbe',
#   'lenses',
#   'billable',
#   'όλο',
#   'vet',
#   'incomefull',
#   'aps',
#   'γλώσσας',
#   'globally',
#   'jira',
#   'closermust',
#   'kind',
#   'assessor',
#   'mathematic',
#   'hence',
#   'εξυπηρετεί',
#   'programmeorganizing',
#   'likewise',
#   'sks',
#   'προκειμένου',
#   'applicable',
#   'approachadvanced',
#   'πιστέυουν',
#   'perfect',
#   'convert',
#   'unixgood',
#   'test',
#   'orientedability',
#   'what',
#   'requisition',
#   'diagnostics',
#   'meetup',
#   'hyderabad',
#   'systemearn',
#   'forwards',
#   'sf',
#   'συμμετέχει',
#   'cpr',
#   'creatively',
#   'onlyclick',
#   'μία',
#   'redis',
#   'room',
#   'winter',
#   'timesconferring',
#   'formassembly',
#   'prn',
#   'kiwis',
#   'menasha',
#   'unloaded',
#   'sap',
#   'repository',
#   'schmuck',
#   'straightforward',
#   'review',
#   'thoroughly',
#   'uranium',
#   'pair',
#   'recent',
#   'cgmp',
#   'lucky',
#   'novation',
#   'response',
#   'ntp',
#   'download',
#   'experienceto',
#   'environmentconsistently',
#   'sr',
#   'strategiesmaintain',
#   'mandatory',
#   'teique',
#   'originally',
#   'box',
#   'expenditure',
#   'stepout',
#   'rf',
#   'laminate',
#   'performancewell',
#   'cosmopolitan',
#   'engage',
#   'nifty',
#   'difference',
#   'gem',
#   'intranet',
#   'some',
#   'evangelical',
#   'postgres',
#   'cto',
#   'captivate',
#   'medical',
#   'iemand',
#   'modernization',
#   'asa',
#   'alternate',
#   'statutory',
#   'wo',
#   'tactic',
#   'youtube',
#   'advantagekey',
#   'timer',
#   'superintendents',
#   'outlookmust',
#   'itinerary',
#   'cprdriver',
#   'nibh',
#   'driven',
#   'environmentfluent',
#   'onyx',
#   'start',
#   'mentality',
#   'projectscoordinate',
#   'ανήκει',
#   'reliably',
#   'reddit',
#   'fossil',
#   'circuitryworking',
#   'trustworthy',
#   'fortune',
#   'scale',
#   'put',
#   'maintenance',
#   'understands',
#   'developmentability',
#   'outline',
#   'igmp',
#   'whole',
#   'χιλιάδες',
#   'differential',
#   'frequency',
#   'depopit',
#   'preferredpreferred',
#   'appropriate',
#   'serviceswork',
#   'slick',
#   'innovator',
#   'essentialworking',
#   'edits',
#   'denver',
#   'usd',
#   'supervisionblueprint',
#   'illustrative',
#   'rail',
#   'procedures',
#   'sterke',
#   'essar',
#   'naturally',
#   'section',
#   'approachproblem',
#   'metricssuccessful',
#   'developmentjob',
#   'onlyplease',
#   'providing',
#   'enclosure',
#   'photovoltaic',
#   'atlanta',
#   'eap',
#   'executioncollaborate',
#   'consultancy',
#   'willing',
#   'necessary',
#   'enrollment',
#   'identifies',
#   'challengespartner',
#   'lever',
#   'clientsworking',
#   'optionspremium',
#   'deaf',
#   'criminal',
#   'qualitiesinterest',
#   'disaster',
#   'bulletin',
#   'independence',
#   'suppliescomputer',
#   'zabbix',
#   'nice',
#   'seiki',
#   'interpersonal',
#   'scratch',
#   'programreputable',
#   'edtech',
#   'selenium',
#   'influencerswrite',
#   'παραπάνω',
#   'subnetting',
#   'publication',
#   'bartender',
#   'compressed',
#   'faq',
#   'multicultural',
#   'managementcreate',
#   'columns',
#   'cooking',
#   'pressureunderstand',
#   'buildingexpert',
#   'architecture',
#   'king',
#   'prngood',
#   'urgencyproficiency',
#   'income',
#   'housekeep',
#   'formal',
#   'wheel',
#   'managementstrong',
#   'feeling',
#   'ήταν',
#   'needssupport',
#   'requestsperform',
#   'coveragededication',
#   'groupsdevelop',
#   'sharepoint',
#   'environmentcontribute',
#   'remove',
#   'pellentesque',
#   'abandonment',
#   'networksexperience',
#   'requirementwe',
#   'workby',
#   'teamengaging',
#   'jennifer',
#   'reception',
#   'post',
#   'north',
#   'you',
#   'beneficialsoft',
#   'receptive',
#   'engineer',
#   'draft',
#   'perfectionist',
#   'mo',
#   'apegga',
#   'insurancesocial',
#   'αναπτύξει',
#   'driver',
#   'organizationproactively',
#   'frequent',
#   'andnetworkingmeet',
#   'objectives',
#   'loss',
#   'maintained',
#   'sky',
#   'wall',
#   'superintendent',
#   'panel',
#   'pup',
#   'worldthe',
#   'redhat',
#   'travelling',
#   'awsadditional',
#   'resultsdevise',
#   'lack',
#   'bt',
#   'correspond',
#   'administrationsetup',
#   'requiredword',
#   'neededanticipate',
#   'corrective',
#   'style',
#   'transform',
#   'statsd',
#   'selection',
#   'blockbuster',
#   'toolsaccount',
#   'at',
#   'vale',
#   'descriptionverify',
#   'allowedpaid',
#   'keycollaborative',
#   'africa',
#   'shipintercom',
#   'policyworkstation',
#   'extend',
#   'culturetrendkite',
#   'hollywood',
#   'extensively',
#   'backgroundfingerprint',
#   'stand',
#   'mount',
#   'lyft',
#   'dna',
#   'guidelinestake',
#   'solaris',
#   'neardesk',
#   'fellowship',
#   'profitablework',
#   'auditsability',
#   'shelter',
#   'stay',
#   'funding',
#   'environmentcompetency',
#   'emc',
#   'fundamentally',
#   'immediately',
#   'scout',
#   'etcstrong',
#   'facilitator',
#   'networkingsage',
#   'managermaintain',
#   'fiber',
#   'spreadsheetsidentify',
#   'constantly',
#   'travelpersonal',
#   'derby',
#   'neededresponsible',
#   'investmentsmanage',
#   'χρόνου',
#   'attain',
#   'nasdaqgm',
#   'attendance',
#   'thousand',
#   'indulge',
#   'nyc',
#   'customersstrong',
#   'trak',
#   'datastrong',
#   'accountslife',
#   'lifecycles',
#   'sit',
#   'analyze',
#   'distributor',
#   'implementationcreate',
#   'wl',
#   'attractive',
#   'ssas',
#   'queriesother',
#   'cottage',
#   'rich',
#   'variety',
#   'plusresponsible',
#   'premise',
#   'fabricationtrackrecord',
#   'openfund',
#   'autonomouslyself',
#   'crmmedical',
#   'groveport',
#   'char',
#   'machinery',
#   'executivesforecast',
#   'compare',
#   'technologyworking',
#   'quadrant',
#   'effortsexperience',
#   'qualificationsdemonstrable',
#   'skillscommercially',
#   'skillsteam',
#   'excitement',
#   'craftsmanship',
#   'fieldexperience',
#   'eeoc',
#   'savvy',
#   'merge',
#   'systemdevelop',
#   'cardextensive',
#   'effectively',
#   'indipendently',
#   'afraid',
#   'light',
#   'evangelist',
#   'corpus',
#   'search',
#   'cpas',
#   'last',
#   'hadoop',
#   'fitexcellent',
#   'revolutionise',
#   'subcontracted',
#   'modelingstrong',
#   'personnelensure',
#   'co',
#   'worth',
#   'clientsyou',
#   'certainly',
#   'interaction',
#   'conceptualize',
#   'gulp',
#   'meeting',
#   'console',
#   'vpn',
#   'companyrecognised',
#   'χαoτικό',
#   'environment',
#   'expect',
#   'εκτιμά',
#   'clarifies',
#   'processing',
#   'teamswe',
#   'accredited',
#   'pando',
#   'highly',
#   'mattis',
#   'skillsable',
#   'met',
#   'angular',
#   'strengthen',
#   'scanningaware',
#   'teamrequires',
#   'personnelcustomer',
#   'thus',
#   'advantageousgood',
#   'chloride',
#   'prudently',
#   'ρυθμοί',
#   'screeningsfree',
#   'ιδέα',
#   'physiology',
#   'drilling',
#   'globe',
#   'rollouts',
#   'url',
#   'necessarily',
#   'incredibly',
#   'perk',
#   'operative',
#   'ό',
#   'experienceproject',
#   'strategize',
#   'brainbow',
#   'toolsdo',
#   'disparate',
#   'skillset',
#   'shortcoming',
#   'opportunties',
#   'proprietary',
#   'publicly',
#   'colorado',
#   'proceed',
#   'multilayer',
#   'testhelp',
#   'lighttpdopenvpnshell',
#   'teamsdevelops',
#   'eliminates',
#   'ώστε',
#   'equipmentshipping',
#   'experiencefamiliarity',
#   'oral',
#   'frac',
#   'clinic',
#   'excelability',
#   'bootstrap',
#   'sight',
#   'giver',
#   'requiredexperience',
#   'weapon',
#   'costof',
#   'range',
#   'realpage',
#   'emergency',
#   'renewal',
#   'copywriter',
#   'integrationsparticipate',
#   'controllable',
#   'το',
#   'component',
#   'instrument',
#   'quantitative',
#   'nmap',
#   'intentpartnering',
#   'breadth',
#   'resultsprobably',
#   'degreed',
#   'udt',
#   'assembler',
#   'basisbuild',
#   'firmbased',
#   'ites',
#   'reseller',
#   'always',
#   'increase',
#   'proarc',
#   'connector',
#   'verification',
#   'ted',
#   'echter',
#   'indicate',
#   'lawreviewing',
#   'optionsfull',
#   'cfr',
#   'extraction',
#   'unknown',
#   'pagessupport',
#   'ppc',
#   'routine',
#   'appts',
#   'opportunities',
#   'lorem',
#   'softwarerelational',
#   'under',
#   'subscribe',
#   'protect',
#   'italy',
#   'account',
#   'authorisation',
#   'metro',
#   'mannerensure',
#   'lun',
#   'ex',
#   'convict',
#   'environmentsa',
#   'chaotic',
#   'mailorder',
#   'kayak',
#   'beautifully',
#   'instantly',
#   'linear',
#   'benefitstravel',
#   'historyfounded',
#   'adult',
#   'testingable',
#   'alarm',
#   'csa',
#   'roofing',
#   'activitiesexperience',
#   'plusstrong',
#   'fidelity',
#   'eg',
#   'technologiesgood',
#   'bright',
#   'managertraining',
#   'clientscoordinate',
#   'telecom',
#   'teamour',
#   'material',
#   'culinary',
#   'discernment',
#   'architectureanalyze',
#   'qualityregularly',
#   'freemium',
#   'series',
#   'groupm',
#   'courtesy',
#   'handed',
#   'delay',
#   'spreader',
#   'reconciliationposition',
#   'stress',
#   'maynard',
#   'managerparticipate',
#   'etiquettedemonstrate',
#   'energize',
#   'documentation',
#   'detailmust',
#   'northwest',
#   'copenhagen',
#   'exception',
#   'apartment',
#   'ideasstaff',
#   'bit',
#   'gis',
#   'shawnee',
#   'descripción',
#   'risk',
#   'independentlystrong',
#   'chinese',
#   'spbu',
#   'appl',
#   'derive',
#   'datawillingness',
#   'satisfy',
#   'requirementsensure',
#   'contribution',
#   'debt',
#   'administrationaccomplishes',
#   'intake',
#   'district',
#   'drawer',
#   'fruit',
#   'install',
#   'boxbee',
#   'learningexperience',
#   'consume',
#   'overnight',
#   'strives',
#   'netherlands',
#   'mindsetstrong',
#   'markdown',
#   'believe',
#   'nhs',
#   'skillscmca',
#   'complement',
#   'cssnice',
#   'spot',
#   'specialized',
#   'upselling',
#   'thrown',
#   'experiance',
#   'forworking',
#   'admin',
#   'eventbrite',
#   'pint',
#   'curiosity',
#   'forget',
#   'bedside',
#   'relax',
#   'veelbelovende',
#   'unternehmens',
#   'environmentgenerous',
#   'prevail',
#   'salesprimary',
#   'bourbon',
#   'porfolio',
#   'rotate',
#   'twice',
#   'campaignsstreamline',
#   'skillscustomer',
#   'aliquam',
#   'preferredprevious',
#   'employerbalanced',
#   'halt',
#   'functionscash',
#   'concept',
#   'description',
#   'organizationsstrong',
#   'entitle',
#   'basisyou',
#   'constructive',
#   'wireframes',
#   'schedulessupport',
#   'mazak',
#   'compelling',
#   'salaryrelaxed',
#   'recruiterdemonstrable',
#   'activitiesintegration',
#   'adwords',
#   'παρέχει',
#   'advancementreputable',
#   'resultsability',
#   'economically',
#   'mas',
#   'operationstranslating',
#   'g',
#   'insurance',
#   'bandwidth',
#   'mnc',
#   'requiredinventory',
#   'compressor',
#   'citizen',
#   'experienceproficiency',
#   'emissionselectric',
#   'webinars',
#   'mysql',
#   'enjoy',
#   'elit',
#   'various',
#   'motif',
#   'intel',
#   'appoint',
#   't',
#   'reconciliation',
#   'installment',
#   'periodic',
#   'server',
#   'requirementsall',
#   'transformer',
#   'each',
#   'attached',
#   'preferredcompetent',
#   'span',
#   'junior',
#   'leave',
#   'red',
#   'accountabilities',
#   'έλαβε',
#   'cameraamazing',
#   'demonstrationsexperience',
#   'accessquiet',
#   'clarity',
#   'resale',
#   'modularisation',
#   'goldengate',
#   'perksentry',
#   'desirableesri',
#   'portalthanks',
#   'budgetdesign',
#   'accountsoptimize',
#   'clearasil',
#   'cadskype',
#   'recruitertekwissen',
#   'oporteat',
#   'forge',
#   'projectsduties',
#   'shuttle',
#   'εργασιακές',
#   'equipmentfamiliarity',
#   'πελατολόγιό',
#   'skillsprofessional',
#   'compact',
#   'opps',
#   'warren',
#   'commanderjenkins',
#   'total',
#   'explore',
#   'turkish',
#   'cssmoderate',
#   'healthcarelocation',
#   'already',
#   'initiativesleadership',
#   'doabout',
#   'club',
#   'naes',
#   'status',
#   'retirement',
#   'permanentjob',
#   'amoung',
#   'patternsdesign',
#   'fulfill',
#   'cusp',
#   'football',
#   'therapy',
#   'paulo',
#   'weekly',
#   'rigidity',
#   'usefully',
#   'behavior',
#   'engagement',
#   'channel',
#   'youfull',
#   'watch',
#   'documentsmanage',
#   'όπως',
#   'conceptsshould',
#   'combined',
#   'recordif',
#   'venerable',
#   'disciplinehave',
#   'expertisestrong',
#   'implementationsability',
#   'pharmaceutical',
#   'tradeshows',
#   'preferredexperience',
#   'rtos',
#   'domestic',
#   'throughput',
#   ...})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def train_vectorizer():
    x = df['text']
    vectorizer = TfidfVectorizer(
        ngram_range=(1,2),
        stop_words='english'
    )
    vectors = vectorizer.fit_transform(x)
    
    return vectorizer, vectors

# %%
import os
import pickle

# %%
def load_model():
    if os.path.exists(MODEL_PATH):
        with open(MODEL_PATH, 'rb') as file:
            classifier, existed_words, vectorizer, vectors = pickle.load(file) 
        return classifier, existed_words, vectorizer, vectors
            
    else:
        print("Model Not Found...")
        print("Training Model...")
        
        classifier, existed_words = train_classifier()
        vectorizer, vectors = train_vectorizer()
        
        with open(MODEL_PATH, 'wb') as file:
            pickle.dump((classifier, existed_words, vectorizer, vectors), file)    
        return classifier, existed_words, vectorizer, vectors

# %%
def print_menu(sentence, category):
    print('J*b System Real / Fake')
    print(f"Text: {sentence}")
    print(f"Category: {category}")
    print("[1] Write Text")
    print("[2] Recommend")
    print("[3] NER")
    print("[4] Exit")
    
    return input("Input Between 1 - 4: ")

# %%
def write_sentence():
    # Min 20 Char and Min 3 Words
    sent = ""
    
    while len(sent.strip()) < 20 or len(sent.strip().split(" ")) < 3:
        sent = input("Input Text Min 20 Char and Min 3 Words: ")
    return sent

# %%
def classify_text(classifier, sentence: str, existed_words):
    feature = feature_extraction(sentence, existed_words)
    category = classifier.classify(feature)
    
    if category == 1:
        return "FAKE"
    else:
        return "REAL"

# %%
def load_NER(nlp, sentence):
    doc = nlp(sentence)
    ents_dict = {}
    
    for ent in doc.ents:
        if ent.label_ not in ents_dict.keys():
            ents_dict[ent.label_] = []
        ents_dict[ent.label_].append(ent.text)
    
    return ents_dict

# %%
def print_NER(ents_dict):
    
    print("NER")
    
    if ents_dict:
        for key, value in ents_dict.items():
            print(f"{key}: {value}")
    else:
        print("No Entities Found")

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend_top_n(vectorizer : TfidfVectorizer, job_vectors, query, topn = 5):
    vectorized_query = vectorizer.transform([query])
    similarity = cosine_similarity(job_vectors, vectorized_query).flatten()
    top_idx = similarity.argsort()[::-1][:topn]
    
    print("Top 5")
    for i, idx in enumerate(top_idx, 1):
        print(f"{i}. {df['title'].iloc[idx]}")

# %%
import spacy

# %%
def menu():
    sent = ''
    cat = ''
    
    # Classifier
    classifier = None
    existed_words = None
    
    # Vectorizer
    vectorizer = None
    vectors = None
    
    # N**ER
    nlp = spacy.load("en_core_web_sm")
    entities_dict = {}
    
    while True:
        choice = print_menu(sent, cat).strip()
        print()
        
        if choice == '1':
            sent = write_sentence()
            
            if classifier is None or existed_words is None or vectorizer is None or vectorizer is None:
                classifier, existed_words, vectorizer, vectors = load_model()
                
        elif choice == '2':
            recommend_top_n(vectorizer, vectors, sent)
        
        elif choice == '3':
            if len(sent.strip()) < 1:
                print("No Text Found...")
                
            entities_dict = load_NER(nlp, sent)
            print_NER(entities_dict)
            
        elif choice == '4':  
            print("Thank You")
            return
        
        else:
            print("Invalid Choice Please Try Again...")
        
        print()

# %%
menu()
# Out:
# J*b System Real / Fake
# Text:
# Category:
# [1] Write Text
# [2] Recommend
# [3] NER
# [4] Exit
#
#
# J*b System Real / Fake
# Text: MBG mas bahlil ganteng lol
# Category:
# [1] Write Text
# [2] Recommend
# [3] NER
# [4] Exit
#
# Top 5
# 1. Information Systems Support Specialist
# 2. Export Documentation Coordinator/Customer Service
# 3. URGENT Part Timers & Full Timers Required.
# 4. Clinic Assistant, Kingston
# 5. Corporate Accountant CPA
#
# J*b System Real / Fake
# Text: MBG mas bahlil ganteng lol
# Category:
# [1] Write Text
# [2] Recommend
# [3] NER
# [4] Exit
#
# NER
# PRODUCT: ['MBG']
# PERSON: ['ganteng lol']
#
# J*b System Real / Fake
# Text: MBG mas bahlil ganteng lol
# Category:
# [1] Write Text
# [2] Recommend
# [3] NER
# [4] Exit
#
# Thank You
